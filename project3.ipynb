# %% [markdown]
# # Climate change and heat-related deaths in USA

# %% [markdown]
# This project studies whether hotter summer temperatures are associated with higher heat-related mortality across U.S. states. The idea is simple. If extreme heat is becoming more common, we want to know whether it is already producing measurable health impacts. We begin by describing the data we use, then we explore the relationship visually through scatter plots, and finally we estimate a regression model to test the relationship more formally.
#
# ##### Heat-related deaths data
#
# The first part of the dataset contains information on heat-related deaths per 100,000 people. This measure adjusts for population size, so it allows us to compare states fairly. A small state and a large state can have very different numbers of total deaths, but the rate per 100k lets us observe the real health impact. The data is reported annually for each state, which gives us a time series within each state and allows us to observe how mortality changes over time.

# %%
import pandas as pd

#Data URL
url = "https://www.ncei.noaa.gov/pub/data/cirs/climdiv/climdiv-tmaxst-v1.0.0-20251117"

#Load raw fixed-width data
tmax_raw = pd.read_fwf(url, header=None)

#Make sure code column is string
tmax_raw[0] = tmax_raw[0].astype(str).str.strip().str.zfill(10)

#Extract year (last 4 digits)
tmax_raw["Year"] = tmax_raw[0].str[-4:].astype(int)

#Extract state code (first 3 digits)
tmax_raw["StateCode3"] = tmax_raw[0].str[:3]

#Rename monthly columns
tmax_raw.columns = [
    "code_year","Jan","Feb","Mar","Apr","May","Jun",
    "Jul","Aug","Sep","Oct","Nov","Dec",
    "Year","StateCode3"
]

#Compute summer max temperature
tmax_raw["summer_max"] = tmax_raw[["Jun","Jul","Aug"]].mean(axis=1)

#Assign readable state names
state_map = {
    "001": "Alabama","002": "Arizona","003": "Arkansas","004": "California",
    "005": "Colorado","006": "Connecticut","007": "Delaware","008": "Florida",
    "009": "Georgia","010": "Idaho","011": "Illinois","012": "Indiana",
    "013": "Iowa","014": "Kansas","015": "Kentucky","016": "Louisiana",
    "017": "Maine","018": "Maryland","019": "Massachusetts","020": "Michigan",
    "021": "Minnesota","022": "Mississippi","023": "Missouri","024": "Montana",
    "025": "Nebraska","026": "Nevada","027": "New Hampshire","028": "New Jersey",
    "029": "New Mexico","030": "New York","031": "North Carolina","032": "North Dakota",
    "033": "Ohio","034": "Oklahoma","035": "Oregon","036": "Pennsylvania",
    "037": "Rhode Island","038": "South Carolina","039": "South Dakota",
    "040": "Tennessee","041": "Texas","042": "Utah","043": "Vermont",
    "044": "Virginia","045": "Washington","046": "West Virginia",
    "047": "Wisconsin","048": "Wyoming","049": "Hawaii","050": "Alaska"
}
tmax_raw["State"] = tmax_raw["StateCode3"].map(state_map)

#Average across climate divisions to get one value per state-year
tmax_state = (
    tmax_raw.groupby(["State","Year"])["summer_max"]
    .mean()
    .reset_index()
)

#Display
tmax_state.head()
# Out:
#      State  Year  summer_max
# 0  Alabama  1895   89.233333
# 1  Alabama  1896   91.166667
# 2  Alabama  1897   92.100000
# 3  Alabama  1898   90.533333
# 4  Alabama  1899   92.066667

# %% [markdown]
# ##### Temperature data
#
# The second part of the dataset includes summer_max, which represents the average maximum summer temperature for each state and year. This variable captures the intensity of heat exposure. We use it as our main explanatory variable because the hypothesis of interest is straightforward:
# hotter summers may lead to more heat-related deaths.

# %%
import pandas as pd

#Load heat-related death data
deaths = pd.read_csv("Multiple Cause of Death, 1999-2020.csv")

#Keep only real states (drop "Total" rows)
deaths = deaths[deaths["State"] != "Total"]

#Make sure Year is integer
deaths["Year"] = pd.to_numeric(deaths["Year"],errors="coerce").astype("Int64")

#Compute deaths per 100k
deaths["deaths_per_100k"] = deaths["Deaths"] / deaths["Population"] * 100000

deaths.head()
# Out:
#   Notes    State  State Code  Year  Year Code  Deaths  Population  Crude Rate  \
# 0   NaN  Alabama         1.0  1999     1999.0    11.0   4430141.0  Unreliable
# 1   NaN  Alabama         1.0  2007     2007.0    14.0   4672840.0  Unreliable
# 2   NaN  Alabama         1.0  2016     2016.0    12.0   4863300.0  Unreliable
# 3   NaN  Alabama         1.0  2017     2017.0    10.0   4874747.0  Unreliable
# 4   NaN  Alabama         1.0  2018     2018.0    16.0   4887871.0  Unreliable
#
#    deaths_per_100k
# 0         0.248299
# 1         0.299604
# 2         0.246746
# 3         0.205139
# 4         0.327341

# %% [markdown]
# ##### Merging the datasets
#
# We merge both datasets using state and year. After merging, each observation represents one state in one year, with both temperature and heat-death information available. This structure produces a panel dataset, which is helpful because it lets us compare states to each other and also examine changes within the same state over time.

# %%
#Merge two data sets
merged = deaths.merge(
    tmax_state,
    on=["State","Year"],
    how="left"
)

#Display
merged.head()
# Out:
#   Notes    State  State Code  Year  Year Code  Deaths  Population  Crude Rate  \
# 0   NaN  Alabama         1.0  1999     1999.0    11.0   4430141.0  Unreliable
# 1   NaN  Alabama         1.0  2007     2007.0    14.0   4672840.0  Unreliable
# 2   NaN  Alabama         1.0  2016     2016.0    12.0   4863300.0  Unreliable
# 3   NaN  Alabama         1.0  2017     2017.0    10.0   4874747.0  Unreliable
# 4   NaN  Alabama         1.0  2018     2018.0    16.0   4887871.0  Unreliable
#
#    deaths_per_100k  summer_max
# 0         0.248299   90.300000
# 1         0.299604   92.633333
# 2         0.246746   91.733333
# 3         0.205139   87.866667
# 4         0.327341   90.000000

# %% [markdown]
# ##### State-level graphs
#
# We begin by creating scatter plots with trend lines for individual states. These visualizations help us form an initial intuition.
#
# In California, the points show a slight upward pattern. Years with higher summer temperatures tend to have slightly higher heat-related death rates. This early pattern suggests a positive relationship.

# %%
#Graph California
import plotly.express as px
from IPython.display import HTML

state = "California"
sub = merged[merged["State"]==state]
fig = px.scatter(
    sub,
    x="summer_max",
    y="deaths_per_100k",
    hover_name="Year",
    title=f"{state}:Heat vs deaths",
    labels={
        "summer_max":"Summer max t",
        "deaths_per_100k":"Heat-related deaths"
    },
    trendline="ols"
)
HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="68c4173a-9457-4399-b4ab-1bea1ec6b12a" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("68c4173a-9457-4399-b4ab-1bea1ec6b12a")) {                    Plotly.newPlot(                        "68c4173a-9457-4399-b4ab-1bea1ec6b12a",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSummer max t=%{x}\u003cbr\u003eHeat-related deaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"AAAAAAA8n0AAAAAAAECfQAAAAAAARJ9AAAAAAABIn0AAAAAAAEyfQAAAAAAAUJ9AAAAAAABUn0AAAAAAAFifQAAAAAAAXJ9AAAAAAABgn0AAAAAAAGSfQAAAAAAAaJ9AAAAAAABsn0AAAAAAAHCfQAAAAAAAdJ9AAAAAAAB4n0AAAAAAAHyfQAAAAAAAgJ9AAAAAAACEn0AAAAAAAIifQAAAAAAAjJ9AAAAAAACQn0AAAAAAAAD4fw=="},"legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"VVVVVVV1VUC8u7u7uxtWQFVVVVVVNVZAzczMzMxsVkDMzMzMzGxWQIiIiIiIKFZAiIiIiIgIVkCZmZmZmZlWQGVmZmZmZlZAm5mZmZl5VkDd3d3d3f1VQGVmZmZm5lVA3d3d3d2dVUCZmZmZmTlWQIiIiIiIaFZAZ2ZmZmZmVkAjIiIiImJWQN3d3d3dnVZAIyIiIiLCVkAAAAAAAKBWQLy7u7u7O1ZAq6qqqqqKVkAAAAAAAAD4fw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"a3+6RWGRrj9s8uEMXri8P1ZWBG6rE7E\u002fjbS79hRKtT8RveA4CMm1P+dl3L2klrU\u002fWees\u002f2twvz8XqdNfktrVP0FJ0kcSqb0\u002fYoYhvyBItD\u002fK5JCkZ7S7PzVOZYfBjbI\u002fyagLCyvPqT+H5WzUY0i+P5qmnSl0Y78\u002ffxtdEyppuD+Vcr9w79m4P0AKMa28C7w\u002fcymKp81swz+QQo7lYCbBP59QZu8DyrI\u002fvGcaVRcJyT9ps\u002f3KoPe8Pw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003edeaths_per_100k = 0.0236317 * summer_max + -1.99264\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.256431\u003cbr\u003e\u003cbr\u003eSummer max t=%{x}\u003cbr\u003eHeat-related deaths=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"VVVVVVV1VUDd3d3d3Z1VQGVmZmZm5lVA3d3d3d39VUCIiIiIiAhWQLy7u7u7G1ZAiIiIiIgoVkBVVVVVVTVWQJmZmZmZOVZAvLu7u7s7VkAjIiIiImJWQGVmZmZmZlZAZ2ZmZmZmVkCIiIiIiGhWQMzMzMzMbFZAzczMzMxsVkCbmZmZmXlWQKuqqqqqilZAmZmZmZmZVkDd3d3d3Z1WQAAAAAAAoFZAIyIiIiLCVkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"oF2WkoxNoj8gBy19RPepP9BeAgPb1rM\u002fsBb4q7gOtj\u002fQmK2b1xC3P5DpjbF14bg\u002fMB\u002fOajQXuj8QVQ4k80y7PzC8I7cytLs\u002f8G+ugNLnuz8wEW+sDom\u002fP1B4hD9O8L8\u002fcHiEP07wvz\u002f4lYcE9xHAP5hJEs6WRcA\u002fqEkSzpZFwD+YZLIqduDAPwgz3VD1rsE\u002fqKdCkqRjwj9IW81bRJfCPyi1kkAUscI\u002fKFLojBJOxD8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222 ...

# %% [markdown]
# In Arizona, the upward trend is stronger. Arizona is hotter in general, and the mortality rate seems more responsive to temperature changes. These first two states make the relationship look intuitive and consistent.

# %%
#Graph Ariizona
import plotly.express as px
from IPython.display import HTML

state = "Arizona"
sub = merged[merged["State"]==state]
fig = px.scatter(
    sub,
    x="summer_max",
    y="deaths_per_100k",
    hover_name="Year",
    title=f"{state}:Heat vs deaths",
    labels={
        "summer_max":"Summer max temperature",
        "deaths_per_100k":"Heat-related deaths per 100k"
    },
    trendline="ols"
)
HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="4f0dcb08-94a6-4a5a-9bac-0b346ae6f8fe" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4f0dcb08-94a6-4a5a-9bac-0b346ae6f8fe")) {                    Plotly.newPlot(                        "4f0dcb08-94a6-4a5a-9bac-0b346ae6f8fe",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"AAAAAAA8n0AAAAAAAECfQAAAAAAARJ9AAAAAAABIn0AAAAAAAEyfQAAAAAAAUJ9AAAAAAABUn0AAAAAAAFifQAAAAAAAXJ9AAAAAAABgn0AAAAAAAGSfQAAAAAAAaJ9AAAAAAABsn0AAAAAAAHCfQAAAAAAAdJ9AAAAAAAB4n0AAAAAAAHyfQAAAAAAAgJ9AAAAAAACEn0AAAAAAAIifQAAAAAAAjJ9AAAAAAACQn0AAAAAAAAD4fw=="},"legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"ERERERGxVkBnZmZmZoZXQIiIiIiIaFdAmZmZmZn5V0BERERERMRXQO\u002fu7u7uTldAeHd3d3dXV0CIiIiIiIhXQEREREREpFdAZWZmZmZmV0Dv7u7u7k5XQBARERERUVdAzczMzMysV0DNzMzMzIxXQN3d3d3dfVdAAAAAAABAV0B3d3d3d1dXQIiIiIiIqFdA3d3d3d29V0CIiIiIiMhXQERERERExFdAm5mZmZk5WEAAAAAAAAD4fw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"I+9t1YV62T9FUjk\u002fDNfgPw4IaGIcs9o\u002fBfxAt+7w5T8s4G\u002fTnDrnP4FTqBRk8uQ\u002fU29bSKm68z8\u002f1ADSQOfzP5IhF5l2FeA\u002fkjvhUedS4T8QyXqX00TuP5wtvEbVh+g\u002fGFPBJIOh7D9uaujqVefoP4npooncCus\u002fQdqVAMiW4T\u002fa97Ga3o7lP9+W7CHQi\u002fc\u002f8CklYETb+D8no61\u002flb\u002f0Pw7\u002f7XkEuPk\u002fe+4iw\u002fBrBkDvKiY\u002fnADwPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003edeaths_per_100k = 0.289857 * summer_max + -26.3237\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.413471\u003cbr\u003e\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"ERERERGxVkAAAAAAAEBXQO\u002fu7u7uTldA7+7u7u5OV0AQEREREVFXQHd3d3d3V1dAeHd3d3dXV0BlZmZmZmZXQIiIiIiIaFdA3d3d3d19V0BnZmZmZoZXQIiIiIiIiFdAzczMzMyMV0BERERERKRXQIiIiIiIqFdAzczMzMysV0Dd3d3d3b1XQERERERExFdARERERETEV0CIiIiIiMhXQJmZmZmZ+VdAm5mZmZk5WEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AMCCN8Vdjb9gyBbwmkHkP4DHfEioa+Y\u002fgMd8SKhr5j8gftTCzrrmP2Ci2zFCqOc\u002fgKLbMUKo5z9goUGKT9LpP0BYmQR2Ieo\u002foHsGzPY47T\u002fAVmW1kHXuP2ANvS+3xO4\u002f4HpsJARj7z+Aqhiz1WTxPzBhcC38s\u002fE\u002fABjIpyID8j\u002fg8iaRvD\u002fzPwCFqkh2tvM\u002fAIWqSHa28z\u002fAOwLDnAX0PzDx8kHXk\u002fc\u002fYKYWbRg3\u002fD8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outline ...

# %% [markdown]
# However, Texas does not fit this pattern. The trend line for Texas slopes downward. In hotter years, Texas does not necessarily experience higher death rates. This contradicts the simple hypothesis and signals that the relationship is not universal. It suggests that other factors — like adaptation, infrastructure, demographics, or reporting differences — may influence heat-related mortality.

# %%
#Graph Texas
import plotly.express as px
from IPython.display import HTML

state = "Texas"
sub = merged[merged["State"]==state]
fig = px.scatter(
    sub,
    x="summer_max",
    y="deaths_per_100k",
    hover_name="Year",
    title=f"{state}:Heat vs deaths",
    labels={
        "summer_max":"Summer max temperature",
        "deaths_per_100k":"Heat-related deaths per 100k"
    },
    trendline="ols"
)
HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="b4d0ace9-da59-4a63-b3d5-740856f7dcd5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b4d0ace9-da59-4a63-b3d5-740856f7dcd5")) {                    Plotly.newPlot(                        "b4d0ace9-da59-4a63-b3d5-740856f7dcd5",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"AAAAAAA8n0AAAAAAAECfQAAAAAAARJ9AAAAAAABIn0AAAAAAAEyfQAAAAAAAUJ9AAAAAAABUn0AAAAAAAFifQAAAAAAAXJ9AAAAAAABgn0AAAAAAAGSfQAAAAAAAaJ9AAAAAAABsn0AAAAAAAHCfQAAAAAAAdJ9AAAAAAAB4n0AAAAAAAHyfQAAAAAAAgJ9AAAAAAACEn0AAAAAAAIifQAAAAAAAjJ9AAAAAAACQn0AAAAAAAAD4fw=="},"legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"eHd3d3dXV0B4d3d3d5dXQGdmZmZmxldAMzMzMzMzV0C8u7u7uztXQO\u002fu7u7urlZAIyIiIiJiV0B4d3d3d7dXQCMiIiIiglZARERERERkV0AjIiIiIuJXQCMiIiIigldAERERERGxUEAjIiIiIuJXQKuqqqqqildAREREREREV0AAAAAAAGBXQGdmZmZmZldAAAAAAABAV0B4d3d3d\u002fdXQIiIiIiIqFdAMzMzMzPzV0AAAAAAAAD4fw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"9dkQR00rxT97rXmbaGrSP4yr06uK0bw\u002fZ84fEbxsxj8q4jgb7WbIP3XbeBNKJsk\u002f+QVRAF1D0j94OZsLNSPOP4XF9G3eL7E\u002fkPPfRB7nwT+NWbEBgb3HPzmQVFAui9A\u002fdW8Wjuro3j\u002faVw0cx6XDP03niHNudMA\u002f1dCOTda9tz9r2xtyCLXBP9\u002fp3SS1zsg\u002f3zVG903Avj\u002fxae4jrYPEP0f\u002fCL2oyM8\u002f4EAi\u002fKeKxz9V3w1UX1jIPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003edeaths_per_100k = -0.00994858 * summer_max + 1.11207\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.453756\u003cbr\u003e\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"ERERERGxUEAjIiIiIoJWQO\u002fu7u7urlZAMzMzMzMzV0C8u7u7uztXQAAAAAAAQFdAREREREREV0B4d3d3d1dXQAAAAAAAYFdAIyIiIiJiV0BERERERGRXQGdmZmZmZldAIyIiIiKCV0CrqqqqqopXQHh3d3d3l1dAiIiIiIioV0B4d3d3d7dXQGdmZmZmxldAIyIiIiLiV0AjIiIiIuJXQDMzMzMz81dAeHd3d3f3V0A="},"xaxis":"x","y":{"dtype":"f8","bdata":"+LfI2mKp3D9YnnJH9LHLPyg6e\u002ffBzco\u002fZNWg2ggsyD8ctnGOkQDIP3wmWujV6sc\u002f2JZCQhrVxz94kNjWTXPHPzRxqYrWR8c\u002fXKmdt\u002fg8xz+Q4ZHkGjLHP7wZhhE9J8c\u002fFPTsWfmZxj\u002fQ1L0Ngm7GP+QldxtPLcY\u002fXOcYg2DWxT+ccMa9T4rFP+D5c\u002fg+PsU\u002fPNTaQPuwxD881NpA+7DEP7SVfKgMWsQ\u002fDAZlAlFExD8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale" ...

# %% [markdown]
# ##### Plots for all states
#
# When we plot all states together, the overall trend becomes very weak. The variation across states is large, and many states do not show a clear relationship between heat and deaths. This reinforces the idea that the simple visual pattern is not strong enough to confirm the hypothesis.

# %%
#Graph all states
import plotly.express as px
from IPython.display import HTML

fig = px.scatter(
    merged,
    x="summer_max",
    y="deaths_per_100k",
    color="State",
    hover_name="State",
    hover_data={"Year":True, "summer_max":True,"deaths_per_100k":True},
    title="Heat vs deaths in all states of USA",
    labels={
        "summer_max":"Summer max temperature",
        "deaths_per_100k":"Heat-related deaths per 100k"
    },
    trendline="ols",
    opacity=0.7
)
fig.update_traces(marker=dict(size=6))
HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="5857ece6-f4ca-4434-b516-eef63329c1ef" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5857ece6-f4ca-4434-b516-eef63329c1ef")) {                    Plotly.newPlot(                        "5857ece6-f4ca-4434-b516-eef63329c1ef",                        [{"customdata":{"dtype":"f8","bdata":"AAAAAAA8n0AAAAAAAFyfQAAAAAAAgJ9AAAAAAACEn0AAAAAAAIifQAAAAAAAjJ9AAAAAAACQn0AAAAAAAAD4fw==","shape":"8, 1"},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState=Alabama\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y}\u003cbr\u003eYear=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama"],"legendgroup":"Alabama","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":6},"mode":"markers","name":"Alabama","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"MzMzMzOTVkCIiIiIiChXQPDu7u7u7lZAeHd3d3f3VUAAAAAAAIBWQLy7u7u7m1ZAMzMzMzNTVkAAAAAAAAD4fw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"XIHUxUPIzz\u002fzoQrctCzTP8Gk5cZflc8\u002fMDTBaP1Byj9Py8YqJ\u002fPUP2DiXuOzftc\u002fwQh2nqk00j+T9C9E0vrGPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003edeaths_per_100k = 0.0118938 * summer_max + -0.791618\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.114791\u003cbr\u003e\u003cbr\u003eState=Alabama\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alabama","marker":{"color":"#636efa","symbol":"circle","size":6},"mode":"lines","name":"Alabama","showlegend":false,"x":{"dtype":"f8","bdata":"eHd3d3f3VUAzMzMzM1NWQAAAAAAAgFZAMzMzMzOTVkC8u7u7u5tWQPDu7u7u7lZAiIiIiIgoV0A="},"xaxis":"x","y":{"dtype":"f8","bdata":"xCcieXk40D8MkRbIyE\u002fRP\u002fQFggAx2NE\u002fNIGLz6YS0j8YfwFIoizSP4Dqfx72KdM\u002fOFyci1fZ0z8="},"yaxis":"y","type":"scatter"},{"customdata":{"dtype":"f8","bdata":"AAAAAAAA+H8=","shape":"1, 1"},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState=Alaska\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y}\u003cbr\u003eYear=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Alaska"],"legendgroup":"Alaska","marker":{"color":"#EF553B","opacity":0.7,"symbol":"circle","size":6},"mode":"markers","name":"Alaska","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAA+H8="},"xaxis":"x","y":{"dtype":"f8","bdata":"UYXdZWlstz8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"State=Alaska\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alaska","marker":{"color":"#EF553B","symbol":"circle","size":6},"mode":"lines","name":"Alaska","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"customdata":{"dtype":"f8","bdata":"AAAAAAA8n0AAAAAAAECfQAAAAAAARJ9AAAAAAABIn0AAAAAAAEyfQAAAAAAAUJ9AAAAAAABUn0AAAAAAAFifQAAAAAAAXJ9AAAAAAABgn0AAAAAAAGSfQAAAAAAAaJ9AAAAAAABsn0AAAAAAAHCfQAAAAAAAdJ9AAAAAAAB4n0AAAAAAAHyfQAAAAAAAgJ9AAAAAAACEn0AAAAAAAIifQAAAAAAAjJ9AAAAAAACQn0AAAAAAAAD4fw==","shape":"23, 1"},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState=Arizona\u003cbr\u003eSummer max temperature=%{x}\u003cbr\u003eHeat-related deaths per 100k=%{y}\u003cbr\u003eYear=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona"," ...

# %% [markdown]
# ##### Regression with fixed effects
#
# To study the relationship more formally, we estimate a regression model that includes both state fixed effects and year fixed effects. These fixed effects help isolate the effect of temperature by controlling for two important sources of variation. State fixed effects control for all characteristics that are constant within each state, such as climate, infrastructure, demographics, or long-term adaptation capacity. Year fixed effects control for national shocks that affect all states in the same year, such as federal policy changes, heat wave reporting standards, or nationwide economic conditions.

# %%
#Analyze statistical significance

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

merged["State"]=merged["State"].astype(str)
merged["Year"]=merged["Year"].astype(str)

df = merged.dropna(subset=["summer_max","deaths_per_100k","State","Year"]).copy()

fe_model = smf.ols(
    formula="deaths_per_100k ~ summer_max + C(Year)",
    data=df
).fit(cov_type="HC3")

#Print results
coef = fe_model.params["summer_max"]
pval = fe_model.pvalues["summer_max"]
print("\nTemperature effect (within-state, controlling for state FE):")
print(f"  Coefficient on summer_max: {coef:.4f}")
print(f"  p-value: {pval:.4f}")
# Out:
# Temperature effect (within-state, controlling for state FE):
#   Coefficient on summer_max: 0.0148
#   p-value: 0.2317

# %% [markdown]
# Once we include both sets of controls, the estimated effect of summer temperature becomes very small and statistically insignificant. The coefficient on summer_max is close to zero, and the p-value is high. This means that, after accounting for differences across states and differences across years, summer temperature does not show a clear or consistent relationship with heat-related deaths in this dataset.
#
# This result suggests that the simple patterns we saw in the state-level plots were not capturing a causal relationship. Other factors not included in the model likely play a major role in explaining heat-related mortality, and temperature alone is not sufficient to predict changes in death rates across states.
